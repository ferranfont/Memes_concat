# %% [markdown]
# # Transformación de ficheros log a csv

# %%
# lectura de códigos Log en VSC

# %%
import pandas as pd
import os
from pandas.errors import EmptyDataError

input_directory = 'logs_txt/'
output_directory = 'processed_csv/'

if not os.path.exists(output_directory):
    os.makedirs(output_directory)

for filename in os.listdir(input_directory):
    if filename.endswith('.log'):
        file_path = os.path.join(input_directory, filename)
        
        try:
            with open(file_path, 'r', encoding='utf-8') as file:
                first_line = file.readline().strip()
        except UnicodeDecodeError:
            print(f"Error de codificación leyendo la primera línea de {filename}")
            continue
        
        try:
            df = pd.read_csv(file_path, skiprows=1, header=0, encoding='utf-8')
        except UnicodeDecodeError:
            print(f"Error de codificación leyendo el archivo {filename}")
            continue
        except EmptyDataError:
            print(f"Archivo vacío o sin datos {filename}, se salta.")
            continue
        
        output_file_path = os.path.join(output_directory, f"{os.path.splitext(filename)[0]}.csv")
        
        with open(output_file_path, 'w', encoding='utf-8') as file:
            file.write(f'{first_line}\n')
        df.to_csv(output_file_path, mode='a', index=False, header=True, encoding='utf-8')
        
        print(f"Archivo {filename} convertido a CSV y guardado en {output_file_path} con comentario.")
# Out:
# Archivo 0x0150102dde85ab026eD16f0c8726250C8e76f514.log convertido a CSV y guardado en processed_csv/0x0150102dde85ab026eD16f0c8726250C8e76f514.csv con comentario.
# Archivo 0x02C0449A89F44965725285599aAd9a7Bf3D6fb43.log convertido a CSV y guardado en processed_csv/0x02C0449A89F44965725285599aAd9a7Bf3D6fb43.csv con comentario.
# Archivo 0x06328E3F0CAb1B7d71083334EA43935bFc6946af.log convertido a CSV y guardado en processed_csv/0x06328E3F0CAb1B7d71083334EA43935bFc6946af.csv con comentario.
# Archivo vacío o sin datos 0x0A84377f142617F182486DA3f81Ed3658fB18c1D.log, se salta.
# Archivo vacío o sin datos 0x0b9fBB037510e9874744148609bc9b06b39aa2Fe.log, se salta.
# Archivo 0x0BF6B4cF5fc7c62f636E186452e6F89e817AD982.log convertido a CSV y guardado en processed_csv/0x0BF6B4cF5fc7c62f636E186452e6F89e817AD982.csv con comentario.
# Archivo 0x0bFf2ee6b0b7E55E2f3E630581DbE4754ABE25fF.log convertido a CSV y guardado en processed_csv/0x0bFf2ee6b0b7E55E2f3E630581DbE4754ABE25fF.csv con comentario.
# Archivo 0x0D1f0F44e148Ae7B1635877A71d76528502DED35.log convertido a CSV y guardado en processed_csv/0x0D1f0F44e148Ae7B1635877A71d76528502DED35.csv con comentario.
# Archivo 0x0e0598915f63D624298D6C322aC65F59447524f9.log convertido a CSV y guardado en processed_csv/0x0e0598915f63D624298D6C322aC65F59447524f9.csv con comentario.
# Archivo 0x0e102Cb276aACc1bD79B69fF116b380004E9E5a8.log convertido a CSV y guardado en processed_csv/0x0e102Cb276aACc1bD79B69fF116b380004E9E5a8.csv con comentario.
# Archivo 0x10E6a4A3c2b6f4E9703401773e141910106e0D6C.log convertido a CSV y guardado en processed_csv/0x10E6a4A3c2b6f4E9703401773e141910106e0D6C.csv con comentario.
# Archivo 0x18b7100529A4C6eE870A2F4021e22646B32Ca472.log convertido a CSV y guardado en processed_csv/0x18b7100529A4C6eE870A2F4021e22646B32Ca472.csv con comentario.
# Archivo 0x18F52A7E60dB86d3B1B9cc5556d2CC71F9f4B9fC.log convertido a CSV y guardado en processed_csv/0x18F52A7E60dB86d3B1B9cc5556d2CC71F9f4B9fC.csv con comentario.
# Archivo 0x1af3F9f9B9625eAcaD38bCAA9067884F42eBc76B.log convertido a CSV y guardado en processed_csv/0x1af3F9f9B9625eAcaD38bCAA9067884F42eBc76B.csv con comentario.
# Archivo 0x1BDC8072b4Bae9028D1B494df049b95D3f34434E.log convertido a CSV y guardado en processed_csv/0x1BDC8072b4Bae9028D1B494df049b95D3f34434E.csv con comentario.
# Archivo 0x1F2fF80689924f4d9a3b6505217b2Fe42D20Cc65.log convertido a CSV y guardado en processed_csv/0x1F2fF80689924f4d9a3b6505217b2Fe42D20Cc65.csv con comentario.
# Archivo 0x244935001a3Cff0A8b0e8f045dA8D1E02A325e27.log convertido a CSV y guardado en processed_csv/0x244935001a3Cff0A8b0e8f045dA8D1E02A325e27.csv con comentario.
# Archivo 0x28f934fa7e4faF929709C49bCb0b47d58dE6D1cd.log convertido a CSV y guardado en processed_csv/0x28f934fa7e4faF929709C49bCb0b47d58dE6D1cd.csv con comentario.
# Archivo 0x2D5100c514abA9b95157b19cc23F60B333055533.log convertido a CSV y guardado en processed_csv/0x2D5100c514abA9b95157b19cc23F60B333055533.csv con comentario.
# Archivo 0x2d7D77e46FE45b4666dDa104347cA74dEe972543.log convertido a CSV y guardado en processed_csv/0x2d7D77e46FE45b4666dDa104347cA74dEe972543.csv con comentario.
# Archivo vacío o sin datos 0x2eCB490685F1009B5890dC9b130f9156e1508be7.log, se salta.
# Archivo 0x2F59C474319fed67b1896668e36b1E9180c3c3f6.log convertido a CSV y guardado en processed_csv/0x2F59C474319fed67b1896668e36b1E9180c3c3f6.csv con comentario.
# Archivo 0x304A95C1183cb9B3E67fccc39621D7Aa0139C06F.log convertido a CSV y guardado en processed_csv/0x304A95C1183cb9B3E67fccc39621D7Aa0139C06F.csv con comentario.
# Archivo 0x31a162a799d75458F5BBBe375D4194D6E7521Eb2.log convertido a CSV y guardado en processed_csv/0x31a162a799d75458F5BBBe375D4194D6E7521Eb2.csv con comentario.
# Archivo 0x343bb79dEa95077973A91366386D9c71E9D12c25.log convertido a CSV y guardado en processed_csv/0x343bb79dEa95077973A91366386D9c71E9D12c25.csv con comentario.
# Archivo 0x3498Ae7f9B91286aBAC344512A3176025bDD6f38.log convertido a CSV y guardado en processed_csv/0x3498Ae7f9B91286aBAC344512A3176025bDD6f38.csv con comentario.
# Archivo 0x3B5cd673FdE90955D3C62D48323e9e6409f3eb33.log convertido a CSV y guardado en processed_csv/0x3B5cd673FdE90955D3C62D48323e9e6409f3eb33.csv con comentario.
# Archivo 0x3e28149881aFF397dB3e23AbA875AF443ca219F8.log convertido a CSV y guardado en processed_csv/0x3e28149881aFF397dB3e23AbA875AF443ca219F8.csv con comentario.
# Archivo 0x400836dAc2804e6730922C26639760b6Fc2BCe5d.log convertido a CSV y guardado en processed_csv/0x400836dAc2804e6730922C26639760b6Fc2BCe5d.csv con comentario.
# Archivo 0x4472E677041e4E7dAecB6FAbA260561D0C950Faf.log convertido a CSV y guardado en processed_csv/0x4472E677041e4E7dAecB6FAbA260561D0C950Faf.csv con comentario.
# Archivo 0x45271352c73ef5C599b86692746DDfe25E959AA8.log convertido a CSV y guardado en processed_csv/0x45271352c73ef5C599b86692746DDfe25E959AA8.csv con comentario.
# Archivo 0x4733C6AfBf9D59ECB0c6e8Cec842e0D5D035731F.log convertido a CSV y guardado en processed_csv/0x4733C6AfBf9D59ECB0c6e8Cec842e0D5D035731F.csv con comentario.
# Archivo 0x4B322a4bec5428C91F3FD1CDb5481ced5a93e6F9.log convertido a CSV y guardado en processed_csv/0x4B322a4bec5428C91F3FD1CDb5481ced5a93e6F9.csv con comentario.
# Archivo 0x4c4276396121b9b1018785BAe5c97Eb2E488499d.log convertido a CSV y guardado en processed_csv/0x4c4276396121b9b1018785BAe5c97Eb2E488499d.csv con comentario.
# Archivo 0x5404084080161dbb0824b3cE0Bd828f0D8266BbF.log convertido a CSV y guardado en processed_csv/0x5404084080161dbb0824b3cE0Bd828f0D8266BbF.csv con comentario.
# Archivo 0x561BD26b85a22C3335B4a1f342f7624669dd7298.log convertido a CSV y guardado en processed_csv/0x561BD26b85a22C3335B4a1f342f7624669dd7298.csv con comentario.
# Archivo 0x5770Ceb2A9eB68b4cE03d35a593573132be3564A.log convertido a CSV y guardado en processed_csv/0x5770Ceb2A9eB68b4cE03d35a593573132be3564A.csv con comentario.
# Archivo 0x57F4c335d5287c367965D2341c5e2C1334D6D5e4.log convertido a CSV y guardado en processed_csv/0x57F4c335d5287c367965D2341c5e2C1334D6D5e4.csv con comentario.
# Archivo 0x5a84272D863Dec3A3C820cCb8ba51EFa91BEb120.log convertido a CSV y guardado en processed_csv/0x5a84272D863Dec3A3C820cCb8ba51EFa91BEb120.csv con comentario.
# Archivo 0x5dc93Bb2ebaC18B258B1B4DDd2154027A14fF817.log convertido a CSV y guardado en processed_csv/0x5dc93Bb2ebaC18B258B1B4DDd2154027A14fF817.csv con comentario.
# Archivo 0x5eB8Ffe74bdf62c8179308d5CafFAF2b30597d25.log convertido a CSV y guardado en processed_csv/0x5eB8Ffe74bdf62c8179308d5CafFAF2b30597d25.csv con comentario.
# Archivo 0x622E4097530476336BF959c4E9A1f8553Ffd319D.log convertido a CSV y guardado en processed_csv/0x622E4097530476336BF959c4E9A1f8553Ffd319D.csv con comentario.
# Archivo 0x65e6eC257df6076be7980d5b79AF063Ab5a4bfe6.log convertido a CSV y guardado en processed_csv/0x65e6eC257df6076be7980d5b79AF063Ab5a4bfe6.csv con comentario.
# Archivo 0x681760352749C52D2Ee265C91AA0CAA1B4bb402b.log convertido a CSV y guardado en processed_csv/0x681760352749C52D2Ee265C91AA0CAA1B4bb402b.csv con comentario.
# Archivo 0x69A0DA0038F1714b4909936183A99631Da25aaaa.log convertido a CSV y guardado en processed_csv/0x69A0DA0038F1714b4909936183A99631Da25aaaa.csv con comentario.
# Archivo 0x69C391d09C86bA398A2E5F3D304058bdA840BB00.log convertido a CSV y guardado en processed_csv/0x69C391d09C86bA398A2E5F3D304058bdA840BB00.csv con comentario.
# Archivo 0x6AB1B66BA8DED182feD56618B4d02751B6a37840.log convertido a CSV y guardado en processed_csv/0x6AB1B66BA8DED182feD56618B4d02751B6a37840.csv con comentario.
# Archivo 0x6b3D35B3ad00537aCF46EF7A06c23F913a9014Ec.log convertido a CSV y guardado en processed_csv/0x6b3D35B3ad00537aCF46EF7A06c23F913a9014Ec.csv con comentario.
# Archivo 0x6c83e6A0B6735863F15cA5BAf4AA4760FFC14f8a.log convertido a CSV y guardado en processed_csv/0x6c83e6A0B6735863F15cA5BAf4AA4760FFC14f8a.csv con comentario.
# Archivo 0x715aFd086294C0792A04AB70F9cA72E7971cDb87.log convertido a CSV y guardado en processed_csv/0x715aFd086294C0792A04AB70F9cA72E7971cDb87.csv con comentario.
# Archivo 0x770e2a0D6c419B5c32516A29EF8279dfAE70ACb0.log convertido a CSV y guardado en processed_csv/0x770e2a0D6c419B5c32516A29EF8279dfAE70ACb0.csv con comentario.
# Archivo 0x7752420B1F6721bC92b245Dc4EFedD19Ec57A50c.log convertido a CSV y guardado en processed_csv/0x7752420B1F6721bC92b245Dc4EFedD19Ec57A50c.csv con comentario.
# Archivo 0x7D946318d1111668D254dd3cAa538F2fbd1b3B44.log convertido a CSV y guardado en processed_csv/0x7D946318d1111668D254dd3cAa538F2fbd1b3B44.csv con comentario.
# Archivo 0x7dd2aEd9BED6a768eE4E522d308B596f6F2f42b6.log convertido a CSV y guardado en processed_csv/0x7dd2aEd9BED6a768eE4E522d308B596f6F2f42b6.csv con comentario.
# Archivo 0x817503A79C96eCAeffFD7C8D457488157ba1f47E.log convertido a CSV y guardado en processed_csv/0x817503A79C96eCAeffFD7C8D457488157ba1f47E.csv con comentario.
# Archivo 0x82dE8C0F681e8165Fc9682585d414a71ee1DD84c.log convertido a CSV y guardado en processed_csv/0x82dE8C0F681e8165Fc9682585d414a71ee1DD84c.csv con comentario.
# Archivo 0x837C1BBa0D3A5D197a5a8398Ac8e40B73d949847.log convertido a CSV y guardado en processed_csv/0x837C1BBa0D3A5D197a5a8398Ac8e40B73d949847.csv con comentario.
# Archivo 0x83a0C9f4faeA85a8284838AA2690937d175B257a.log convertido a CSV y guardado en processed_csv/0x83a0C9f4faeA85a8284838AA2690937d175B257a.csv con comentario.
# Archivo 0x85EeA72BEFeAAEE57E24D4cB015c75537f7B560d.log convertido a CSV y guardado en processed_csv/0x85EeA72BEFeAAEE57E24D4cB015c75537f7B560d.csv con comentario.
# Archivo 0x88C52791f83F4c5baF2a459aF202601507d97203.log convertido a CSV y guardado en processed_csv/0x88C52791f83F4c5baF2a459aF202601507d97203.csv con comentario.
# Archivo 0x8a46ef3A3fF0973Ea5639C7D04b9a5B94794F239.log convertido a CSV y guardado en processed_csv/0x8a46ef3A3fF0973Ea5639C7D04b9a5B94794F239.csv con comentario.
# Archivo 0x8A5AD91808596E0d972e1fd89B87cC43b680ed50.log convertido a CSV y guardado en processed_csv/0x8A5AD91808596E0d972e1fd89B87cC43b680ed50.csv con comentario.
# Archivo 0x8Adee31273Bc854f26ad4aa25a70B16100F3E4dd.log convertido a CSV y guardado en processed_csv/0x8Adee31273Bc854f26ad4aa25a70B16100F3E4dd.csv con comentario.
# Archivo 0x8b8D2CC5C647a59f68Fd78A73BbB42CdC9FDFD08.log convertido a CSV y guardado en processed_csv/0x8b8D2CC5C647a59f68Fd78A73BbB42CdC9FDFD08.csv con comentario.
# Archivo 0x8d4cCCC644265FB9d62033EE2328380c47953d61.log convertido a CSV y guardado en processed_csv/0x8d4cCCC644265FB9d62033EE2328380c47953d61.csv con comentario.
# Archivo 0x8F7b54D6C40F9a9f57D7e1DBAF060c3F85D0b8e6.log convertido a CSV y guardado en processed_csv/0x8F7b54D6C40F9a9f57D7e1DBAF060c3F85D0b8e6.csv con comentario.
# Archivo 0x911C87bbAd0156c5C606C783041c27ddf1b1CA63.log convertido a CSV y guardado en processed_csv/0x911C87bbAd0156c5C606C783041c27ddf1b1CA63.csv con comentario.
# Archivo 0x91cfA50D9055D6c6b7bE3E92b4BB22Ff528FFa00.log convertido a CSV y guardado en processed_csv/0x91cfA50D9055D6c6b7bE3E92b4BB22Ff528FFa00.csv con comentario.
# Archivo 0xa2c1A2042EE6E79f83384fcCe9484FB0CC3BCEdA.log convertido a CSV y guardado en processed_csv/0xa2c1A2042EE6E79f83384fcCe9484FB0CC3BCEdA.csv con comentario.
# Archivo 0xA6DEdc249294AEA38142717cb5Bb7F56E8114CcF.log convertido a CSV y guardado en processed_csv/0xA6DEdc249294AEA38142717cb5Bb7F56E8114CcF.csv con comentario.
# Archivo 0xae74f580e407224455fbc5f06892b01e93E89EAa.log convertido a CSV y guardado en processed_csv/0xae74f580e407224455fbc5f06892b01e93E89EAa.csv con comentario.
# Archivo 0xb057934398F8dd54aaB0Adbd14045Da90CbeB31D.log convertido a CSV y guardado en processed_csv/0xb057934398F8dd54aaB0Adbd14045Da90CbeB31D.csv con comentario.
# Archivo 0xB0AB682FC4Ba835BDcfc72113618444F5D18d26e.log convertido a CSV y guardado en processed_csv/0xB0AB682FC4Ba835BDcfc72113618444F5D18d26e.csv con comentario.
# Archivo 0xB36D7f33A6C0Be44C06CD4461e0Cd0B775297af1.log convertido a CSV y guardado en processed_csv/0xB36D7f33A6C0Be44C06CD4461e0Cd0B775297af1.csv con comentario.
# Archivo 0xB50952123C30Ba2146c32d36c7ccCEDe8941Cb6b.log convertido a CSV y guardado en processed_csv/0xB50952123C30Ba2146c32d36c7ccCEDe8941Cb6b.csv con comentario.
# Archivo 0xc27646e7FD2344c3F852362d464a15Ec2Cc848F1.log convertido a CSV y guardado en processed_csv/0xc27646e7FD2344c3F852362d464a15Ec2Cc848F1.csv con comentario.
# Archivo 0xc56C5ac1C729cB596ed0f01aA3D327320FE1775a.log convertido a CSV y guardado en processed_csv/0xc56C5ac1C729cB596ed0f01aA3D327320FE1775a.csv con comentario.
# Archivo 0xc62C8389A5F4AF816304D57CfCf10C9C95b234C5.log convertido a CSV y guardado en processed_csv/0xc62C8389A5F4AF816304D57CfCf10C9C95b234C5.csv con comentario.
# Archivo 0xC97Ebfe92Eb0C6A58cAA322B9116b724dB832Cf7.log convertido a CSV y guardado en processed_csv/0xC97Ebfe92Eb0C6A58cAA322B9116b724dB832Cf7.csv con comentario.
# Archivo 0xC9f3FCB2Facbaa441f16bd8486ab81E1F6c4701d.log convertido a CSV y guardado en processed_csv/0xC9f3FCB2Facbaa441f16bd8486ab81E1F6c4701d.csv con comentario.
# Archivo 0xCbAf06ab4Dd44d532a1C65F416F08c9BFC537Ec9.log convertido a CSV y guardado en processed_csv/0xCbAf06ab4Dd44d532a1C65F416F08c9BFC537Ec9.csv con comentario.
# Archivo 0xcef8b3e86E59865D426433Dd9d3212C51660065c.log convertido a CSV y guardado en processed_csv/0xcef8b3e86E59865D426433Dd9d3212C51660065c.csv con comentario.
# Archivo 0xd0966Bf79809b2B56dc13431086f068656E70fCe.log convertido a CSV y guardado en processed_csv/0xd0966Bf79809b2B56dc13431086f068656E70fCe.csv con comentario.
# Archivo 0xd0b4b58fA1d0E33e144e8e77b8e7dbd26BDF8311.log convertido a CSV y guardado en processed_csv/0xd0b4b58fA1d0E33e144e8e77b8e7dbd26BDF8311.csv con comentario.
# Archivo vacío o sin datos 0xd2a2aC77F03725bedfC5e902AA215e041BBd6589.log, se salta.
# Archivo 0xd484Dc48b315664e88e22531B069185468808e4d.log convertido a CSV y guardado en processed_csv/0xd484Dc48b315664e88e22531B069185468808e4d.csv con comentario.
# Archivo 0xDA4a94A7e4b45E72148d721383d89F1cdD90D6f0.log convertido a CSV y guardado en processed_csv/0xDA4a94A7e4b45E72148d721383d89F1cdD90D6f0.csv con comentario.
# Archivo 0xdaA47135Cef05a1c42c5E0f4bfcAE6d1F933c9F5.log convertido a CSV y guardado en processed_csv/0xdaA47135Cef05a1c42c5E0f4bfcAE6d1F933c9F5.csv con comentario.
# Archivo 0xDEd99323cDFD5513A7E55CDC3b44d621f39fF999.log convertido a CSV y guardado en processed_csv/0xDEd99323cDFD5513A7E55CDC3b44d621f39fF999.csv con comentario.
# Archivo 0xE2d9a2f667A83E37286Be67ADe19627196ff6EA6.log convertido a CSV y guardado en processed_csv/0xE2d9a2f667A83E37286Be67ADe19627196ff6EA6.csv con comentario.
# Archivo 0xe436F5a05D0D132058517B7f68f07c05B88d8820.log convertido a CSV y guardado en processed_csv/0xe436F5a05D0D132058517B7f68f07c05B88d8820.csv con comentario.
# Archivo 0xE9a5cf8666F8517f999Be35dFe95cB4fb780c072.log convertido a CSV y guardado en processed_csv/0xE9a5cf8666F8517f999Be35dFe95cB4fb780c072.csv con comentario.
# Archivo 0xf1C83Cf9ce8D800C91f759a2Fea3d01019156118.log convertido a CSV y guardado en processed_csv/0xf1C83Cf9ce8D800C91f759a2Fea3d01019156118.csv con comentario.
# Archivo 0xf345De38189829370D97183E729C8b5E9598Ca94.log convertido a CSV y guardado en processed_csv/0xf345De38189829370D97183E729C8b5E9598Ca94.csv con comentario.
# Archivo 0xf3E6Fef9f333978CE0F61c3ef53a23aFec38CA89.log convertido a CSV y guardado en processed_csv/0xf3E6Fef9f333978CE0F61c3ef53a23aFec38CA89.csv con comentario.
# Archivo 0xf7898F34648d8262cA072cb0612D90F9Fd22ba08.log convertido a CSV y guardado en processed_csv/0xf7898F34648d8262cA072cb0612D90F9Fd22ba08.csv con comentario.
# Archivo 0xf8f97ca85B3408DD5acDb0F8F2A40f14a210308B.log convertido a CSV y guardado en processed_csv/0xf8f97ca85B3408DD5acDb0F8F2A40f14a210308B.csv con comentario.
# Archivo 0xfE34af1663B7ed0e50FE7830c8E61412F73c65f3.log convertido a CSV y guardado en processed_csv/0xfE34af1663B7ed0e50FE7830c8E61412F73c65f3.csv con comentario.
